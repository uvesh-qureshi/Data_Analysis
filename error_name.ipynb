# %%
# Name error


x=10
print(y)
# Out:
# 10

# %%
# value error


name=[2,3,4,5,7]
name.remove(8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 5
#       1 # value error
#       4 name=[2,3,4,5,7]
# ----> 5 name.remove(8)
#
# ValueError: list.remove(x): x not in list

# %%
# syntax error

def add():
print('hello')

# %%
#index errror

name=[12,34,122]
print(name[2])
# Out:
# 122

# %%
t=10
print(y)
# Out:
# 10

# %%
# name=34
# print(tarun)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 name=34
# ----> 2 print(tarun)
#
# NameError: name 'tarun' is not defined

# %%
# name=[2,3,4,5,6]
# name.remove(45)


# name=[2,35,4]
# print(name[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 6
#       1 # name=[2,3,4,5,6]
#       2 # name.remove(45)
#       5 name=[2,35,4]
# ----> 6 print(name[4])
#
# IndexError: list index out of range

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 f=open('uvuifdiuiduiduui','r')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'uvuifdiuiduiduui'

# %%
class student:
    def hello(self):
        return 'hello'
s=student()
s.helo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 5
#       3         return 'hello'
#       4 s=student()
# ----> 5 s.helo
#
# AttributeError: 'student' object has no attribute 'helo'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 x=10
#       2 y='23'
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
name=56667
print(tarun)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 name=56667
# ----> 2 print(tarun)
#
# NameError: name 'tarun' is not defined

# %%
a='45'
b=56
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 a='45'
#       2 b=56
# ----> 3 print(a+b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
name=[2,57,7,8]
print(name[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 name=[2,57,7,8]
# ----> 2 print(name[4])
#
# IndexError: list index out of range

# %%
# name=445
# print(f)

valuw=[2,3,45,6]
valuw.remove(434)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 5
#       1 # name=445
#       2 # print(f)
#       4 valuw=[2,3,45,6]
# ----> 5 valuw.remove(434)
#
# ValueError: list.remove(x): x not in list

# %%
f=open('file.txt','r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 f=open('file.txt','r')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'

# %%
class student:
    def hello(self):
        return 'hello'
    
st=student()
st.hel()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 6
#       3         return 'hello'
#       5 st=student()
# ----> 6 st.hel()
#
# AttributeError: 'student' object has no attribute 'hel'

# %%
try:
     a=int(input("enter the any input:"))
     b=int(input("enter the any input:"))
     print(a/b)
     
except(ZeroDivisionError,ValueError) as e:
    print("Error",e)
finally:
    print(66+45)
# Out:
# Error division by zero
# 111

# %%
age =-1
if age<18:
    raise ValueError("age is not define")

# %%
class UveshError(Exception):
    pass
age =-1
if age<0:
    raise UveshError("age is not define a=int(input)")
# Out:
# ---------------------------------------------------------------------------
# UveshError                                Traceback (most recent call last)
# Cell In[5], line 5
#       3 age =-1
#       4 if age<0:
# ----> 5     raise UveshError("age is not define")
#
# UveshError: age is not define

# %%
try:
    a=int(input("enter thr number"))
    print(a)
except KeyboardInterrupt:
    print('input dalo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 try:
# ----> 2     a=int(input("enter thr number"))
#       4     print(a)
#       5 except KeyboardInterrupt:
#
# ValueError: invalid literal for int() with base 10: 'xc'

# %%
# class Exp:
#     def Exceptionerror():
#         try:
#             f=open('uvesh.txt','r')
#             print(f.read())
#         except(FileNotFoundError) as e:
#             print(e)
            
# Exp().Exceprionerror()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 9
#       6         except(FileNotFoundError) as e:
#       7             print(e)
# ----> 9 Exp().Exceprionerror()
#
# AttributeError: 'Exp' object has no attribute 'Exceprionerror'

# %%
# thirt-part Module:Numpy,pandas,Matplotlib,Seaborn

# %%
# Numpy

# %%
import  numPy  as np

li=[1,2,3,4,5,6]
li=[x+5 for x in li]
print(li)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import  numpy as np
#       3 li=[1,2,3,4,5,6]
#       4 li=[x+5 for x in li]
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import numpy as np
li=[1,2,3,5]
print(li)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       2 li=[1,2,3,5]
#       3 print(li)
#
# ModuleNotFoundError: No module named 'numpy'
