# %%
# class or object question
class My_class:
    a='shivam'
    b='uvesh'
myclass=My_class()

myclass.a
myclass.b
# Out:
# 'uvesh'

# %%
# class My_class:
#     a='tarun'
#     b='uvesh'
#     def conc(self):
#         return self.a +" " +self.b
    
    
# myclass=My_class()
# print(myclass.a)
# print(My_class.b)   
# print(myclass.conc()) 


# class My_class():
#     a='tarun'
#     b='akash'
#     c='shivam'
#     def fun(self):
#         return self.a +"   " +self.b
    
# myclass=My_class()

# print(myclass.a)    
# print(myclass.b)  
# print(myclass.fun())  
# print(myclass.c)






class My_class:
    a='rahul'
    b='somiya'
    c='tarun'
    
    
    def fun(self):
        return (self.a +" "+ self.b)
    
myclass=My_class()


print(myclass.a)
print(myclass.b)    
print(myclass.fun())
# Out:
# rahul
# somiya
# rahul somiya

# %%
# class My_class:
#     def __init__(self,a,b,c):
#         self.a=a
#         self.b=b
#         self.c=c
#         def conc(self):
#             return self.a+" "+self.b
        
#         def multuply(self,count):
#             return self.c*count
        
        
# myclass=My_class('abhay','tarun',60)


# print(myclass.a)
# print(myclass.b)





# class My_class:
#     def __init__(self, a, b, c):
#         self.a = a
#         self.b = b
#         self.c = c

#     def conc(self):
#         return self.a + " " + self.b

#     def multuply(self, count):
#         return self.c * count


# myclass = My_class('abhay', 'tarun', 60)

# print(myclass.a)
# print(myclass.b)
# print(myclass.conc())
# print(myclass.multuply(3))






# class My_class:
#     def __init__(self,a,b,c):
#         self.a=a
#         self.b=b
#         self.c=c
#     def conc(self,count):
#         return self.c*count
    
    
# myclass=My_class('tarun','shivam',23)


# print(myclass.a)
# print(myclass.b)
# print(myclass.conc(9))

# %%
# class My_class:
#     def __init__(self,a,b,c,d):
#         self.a=a
#         self.b=b
#         self.c=c
#         self.d=d
        
        
        
#     def sum(self,s):
#         return self.c+s
    
#     def mult(self,m):
#         return self.d*m
    
    
    
    
# myclass=My_class('tarun','sahil',45,23)


# print(myclass.a)  
# print(myclass.b)
# print(myclass.sum(4))
# print(myclass.mult(3))

# %%
class My_class:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    
        
    def sum(self):
        return self.a+self.b
    def mult(self):
        return self.a*self.b
    
    def sub(self):
        return self.a-self.b
    
    
    def div(self):
        return self.a/self.b
    
    
myclass=My_class(12,23)


print(myclass.sum())
print(myclass.mult())
print(myclass.sub())
print(myclass.div())
# Out:
# 35
# 276
# -11
# 0.5217391304347826

# %%
class bank:
    def __init__(self,name,acc_no,balance):
        self.name=name
        self.acc_no=acc_no
        self.balance=balance
    def detail(self):
        print("the account number is",self.acc_no)
        print("the account number is",self.balance)
bank=bank("shubham",1234,345)    
bank.detail()
# Out:
# the account number is 1234
# the account number is 345

# %%
class bank:
    def __init__(self,balance,account_no,name):
        
        self.name=name
        self.account_no=account_no
        self.balance=balance
    def detail(self):
        print("the account of the bank",self.account_no)
        print("the account of balance",self.balance)
        print("the name of the bank",self.name) 
        
Bank=bank('tarun',123,556)
Bank.detail()
# Out:
# the account of the bank 123
# the account of balance tarun
# the name of the bank 556

# %%
class first:
    def __init__(self,name,father_name,mother_name,a,b):
        self.name=name
        self.father_name=father_name
        self.mother_name=mother_name
        self.a=a
        self.b=b
        
        
        
    def detail(self):
        print("the name of the student is",self.name)
        print("the name of the father is",self.father_name)
        print("the name of the mother is ",self.mother_name)
        
    def sum(self):
        print("the sum of the variable",self.a)
        
        print('the sum of the b is',self.b) 
        
        
bank=first('uvesh','sumit','anno',12,34)

bank.detail()  
bank.sum()
# Out:
# the name of the student is uvesh
# the name of the father is sumit
# the name of the mother is  anno
# the sum of the variable 12
# the sum of the b is 34

# %%
class element:
    def __init__(self,first_sem,sec_sem,third_sem,four_sem):
        self.first_sem=first_sem
        self.sec_sem=sec_sem
        self.third_sem=third_sem
        self.four_sem=four_sem
        
        
    def detail(self):
        print('the first sem percentage is',self.first_sem)
        print('the second sem percentage is',self.sec_sem) 
        
    def percentage(self):
        print('the thirs sem percentage is ',self.third_sem)
        print("the four sem percentage is",self.four_sem)
             
first=element(23.3,26.5,90.5,45.6)
first.detail()
first.percentage()
# Out:
# the first sem percentage is 23.3
# the second sem percentage is 26.5
# the thirs sem percentage is  90.5
# the four sem percentage is 45.6

# %%
# inheritance question
class bank:
    def __init__(self,name,acc_no,balance):
        self.name=name
        self.acc_no=acc_no
        self.balance=balance
    def deposite(self,amount): 
        if amount>0:
            self.balance+=amount

# %%
#single inheritance in python

class parent:
    def faring_land(self):
        print("i have 100  access lan for  farming")
    def vehilcle(self):
        print('i have tractor and sedanlor ') 
class child(parent):
    def flat(self):
        print("i have 2 bike flat in noida ")
    def car(self):
            print(' i have a fortinder')
p=parent()
ch=child()
ch.faring_land() 
ch.vehilcle()
ch.flat()
ch.car()
# Out:
# i have 100  access lan for  farming
# i have tractor and sedanlor
# i have 2 bike flat in noida
#  i have a fortinder

# %%
# class parent:
#     def semister_one(self):
#         print("i m uvesh in currently 7 semister tudy")
        
#     def semister_two(self):
#         print("i have a student of b tech") 
        
        
# class child:
#     def first(self):
#         print("i m tarun kumar") 
        

# class model(child,parent):
#     def toy(self):
#         print("hello sir")


# pa = parent()
# ch = child()
# mo = model()
# mo.toy()
# mo.first()




# multiple inheritance

class first:
    def company(self):
        print("i have owner of company")
        
    def company_one(self):
        print("hello sir who are you")
class second:
    
    def manager(self):
        print("may i comming sir")
        
        
    def manager_one(self):
        print("hey i m uvesh")
        
        
class third(first,second):
    def employee(self):
        print("i m emplyee this company")
    def employee_one(self):
        print("i m  employee of company")       
fa=first()
fa.company()
th=third()
th.manager_one()

th.company_one()

th.employee_one()
# Out:
# i have owner of company
# hey i m uvesh
# hello sir who are you
# i m  employee of company

# %%
# multilevel inheritance


class parent:
    def first(self):
        print('i m b tech student')
        
    def first_one(self):
        print(" i m student ")
class child(parent):
    def second(self):
        print('hey i m uvesh')
    def child_one(self):
        print('i m uvesh')
        
class toy(child):
    def third(self):
        print("hello sir kaise ho")
        

    def third_one(self):
        print(' you are beautiful pic')
pa=parent()
ch=child()


to=toy()

to.first()    

to.first_one()
to.second()
to.child_one()
# Out:
# i m b tech student
#  i m student
# hey i m uvesh
# i m uvesh

# %%
# Herarichal Inheritance
class Parent:
    def farming_land(self):
        print("I have 100 acres land for farming")
    def vehicle(self):
        print(" I have Tractor and Sedan Car")
class Child(Parent):
    def flat(self):
        print("i have 2 bhk flat in Noida")
    def car(self):
        print("I have a Fortuner car")
class Grand_son(Parent):
    def toy(self):
        print("I have a elephant toy")
    def bicyle(self):
        print("I have triclyle Also")
        
    
ga=Grand_son()
ga.toy()
ga.farming_land()
# Out:
# I have a elephant toy
# I have 100 acres land for farming

# %%
# polymorphsim 


# class main:
#     def hello(self):
#         print('hello class')
#     def hello(self,name):
#         print('hello ',name)
# class sub(main):
#     def hello(self):
#         print('hello noida')
# mn=main()
# sb=sub()
# sb.hello()
    
    
class main:
    def name(self):
        print('hello uvesh qureshi')
    def
# Out:
#   Cell In[18], line 20
#     def
#             ^
# SyntaxError: invalid syntax

# %%
# AbstractMEthod

# %%
from datetime import datetime
# datetime.today()
datetime.weekday(datetime.today())
# Out:
# 5

# %%
from datetime import datetime
datetime.today()
# Out:
# datetime.datetime(2025, 11, 22, 13, 10, 14, 256939)

# %%
import random

a=['sonu','moionu','kartik','hello','arun']

random.choice(a)
# Out:
# 'moionu'

# %%
                       # class and object


class Employee:
    name='Harry'
    language='py'
    salary=12000
    
em=Employee()
print(f"the name of the {em.name} and the salary of (em.salary)")
rohan=Employee()
rohan.name='Rohan tarun'
print(rohan.language,rohan.salary,rohan.name)
# Out:
# the name of the Harry and the salary of (em.salary)
# py 12000 Rohan tarun

# %%
# instance and class attribute
class Employee:
    name='Harry'
    language='py'
    salary=12000
    
em=Employee()
em.name='uvesh qureshi'
print(em.salary,em.language,em.name)
rohan=Employee()
rohan.name='Rohan tarun'
print(rohan.language,rohan.salary,),
# Out:
# 12000 py uvesh qureshi
# py 12000
# (None,)

# %%
# self method

# %%
class Employee:
    language='python'
    salary=12000
    def getInfo(self):
        print(f'the salary of {self.salary} and the language of {self.language}')
    def greet(self):
        print('good morning sir')
        
harry=Employee()
harry.language='javascript'
# Employee.getInfo(harry)


harry.getInfo()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 13
#      10 harry.language='javascript'
#      11 # Employee.getInfo(harry)
# ---> 13 Employee.greet()
#      15 harry.getInfo()
#
# TypeError: Employee.greet() missing 1 required positional argument: 'self'

# %%
class Employee:
    language='python'
    salary=12000
    
    
    def __init__(self,name,salary,language):
        self.name=name
        
        self.salary=salary
        self.language=language
        print('i m create an object')
    
    
    
    
    

    def getInfo(self):
        print(f'the salary of {self.salary} and the language of {self.language}')
    def greet(self):
        print('good morning sir')
        
harry=Employee('uvesh',130000,'java')
harry.name='harry'
print(harry.name,harry.salary,harry.language)
# Out:
# i m create an object
# harry 130000 java

# %%
# inheritance py


class Employee:
    company='ITC'
    def show(self):
        print(f'the naem is {self.name} and the salary is {self.salary}')
class Programmer:
    company='tata'
    def show(self):
        print(f"the name is {self.name} and the salary is {self.salary}")    
    def showlanguage(self):
        print(f'the name is {self.name} and he is good person of {self.language} language')
em=Employee()
pr=Programmer()
print(em.company,pr.company)
# Out:
# ITC tata

# %%
# multiple innheritance



class Employee:
    company='ITC'
    def show(self):
       
       
        print(f'the naem is {self.name} and the salary is {self.salary}')
        
        
        
class Coder:
    def element(self):
        print(f'the naem is {self.name} and the salary is {self.salary}')        
class Programmer:
    
    
    
    
    company='tata'
    def show(self):
        print(f"the name is {self.name} and the salary is {self.salary}")    
    def showlanguage(self):
        print(f'the name is {self.name} and he is good person of {self.language} language')
em=Employee()
pr=Programmer()
print(em.company,pr.company)

# %%
# super_method



class Employee:
    def __init__(self):
        print('constructor of employee')
    a=1
class Programmer(Employee):
    def __init__(self):
        super(). __init__()
        
        print('Constructor of Programmer')
        
    b=2
class Manager(Programmer):
    def __init__(self):
        super().__init__()
    
        print('constructor of manager')
        
    c=3
o=Manager()
print(o.a,o.b, o.c)
# Out:
# constructor of employee
# Constructor of Programmer
# constructor of manager
# 1 2 3

# %%
# encapsulation

# %%
class Car:
    def __init__(self,brand,model):
        self.brand=brand
        self.model=model
    
    
    def get_brand(self):
        return self.brand+'hello uvesh'
         
        
    def full_name(self):
        return f'{self.brand} {self.model}'    
    
    
class ElectricCar(Car):
    def ___init__(self,brand,model,battery_size):
        super().__init__(brand,model)
        self.battery_size=battery_size
        
my_tasla=ElectricCar('tasla','model s')   
print(my_tasla.model)    

print()

my_car=Car('tata','safari')
print(my_car.get_brand)
print(my_car.model)
print(my_car.full_name())
print(my_car.get_brand())
# Out:
# model s
#
# <bound method Car.get_brand of <__main__.Car object at 0x000002A4E84F3520>>
# safari
# tata safari
# tatahello uvesh

# %%
# polymorphsim 

class Car:
    total_car=0
   
    def __init__(self,brand,model):
        self.brand=brand
        self.model=model
    
    
    def get_brand(self):
        return self.brand+'hello uvesh'
         
        
    def full_name(self):
        return f'{self.brand} {self.model}'
    def fuel_type(self):
        return 'Electric charge'    
    
    
class ElectricCar(Car):
    def ___init__(self,brand,model,battery_size):
        super().__init__(brand,model)
        self.battery_size=battery_size
    def fuel_type(self):
        return 'Electric Charge' 
        
my_tasla=ElectricCar('tasla','model s')   
print(my_tasla.model)    

print()

my_car=Car('tata','safari')
print(my_car.get_brand)
print(my_car.model)
print(my_car.fuel_type())
print(my_car.full_name())
print(my_car.get_brand())
safari=Car('tata','safari')
print(safari.fuel_type())
# Out:
# model s
#
# <bound method Car.get_brand of <__main__.Car object at 0x000002A4E72FE230>>
# safari
# Electric charge
# tata safari
# tatahello uvesh
# Electric charge

# %%
# first question


class circule:
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius**2
    
    def parameter(self):
        return 2*3.14*self.radius
radius=float(input("enter the radous of circule and area"))
ar=circule(radius)


print(ar.radius)   
print(ar.area())
print(ar.parameter())
# Out:
# 2.0
# 12.56
# 12.56

# %%
# class Person:
#     def __init__(self, name, age):
#         self.__name = name      # private variable
#         self.__age = age        # private variable
    
#     # getter for name
#     def get_name(self):
#         return self.__name
    
#     # setter for name
#     def set_name(self, name):
#         self.__name = name
    
#     # getter for age
#     def get_age(self):
#         return self.__age
    
#     # setter for age
#     def set_age(self, age):
#         if age > 0:
#             self.__age = age
#         else:
#             print("Age must be positive!")

# # object
# p = Person("Rahul", 20)

# print(p.get_name())  # Rahul
# print(p.get_age())   # 20

# p.set_age(25)
# print(p.get_age())   # 25





# class BankAccount:
#     def __init__(self, account_holder, balance):
#         self.account_holder = account_holder
#         self.__balance = balance   # private variable

#     # Getter method
#     def get_balance(self):
#         return self.__balance

#     # Setter method → deposit
#     def deposit(self, amount):
#         if amount > 0:
#             self.__balance += amount
#             print(f"{amount} deposited.")
#         else:
#             print("Amount must be positive.")

#     # Setter method → withdraw
#     def withdraw(self, amount):
#         if amount <= self.__balance:
#             self.__balance -= amount
#             print(f"{amount} withdrawn.")
#         else:
#             print("Insufficient balance!")

# # Object
# acc = BankAccount("Rohit", 1000)

# print(acc.get_balance())   # 1000

# acc.deposit(500)           
# print(acc.get_balance())   # 1500

# acc.withdraw(300)          
# print(acc.get_balance())   # 1200

# %%
# 3. arithmetic operation




class Calculator:
    
    
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def add(self):
     return self.x+self.y
    
    def multiply(self):
        return self.x*self.self.y
    def substration(self):
        return self.x-self.y
    
    def divide(self):
        return self.x/self.y
    
    
    def module(self):
        return self.x%self.y
    
    
    
c=Calculator(23,45)
print("addition x+y",c.add())
# Out:
# addition x+y 68

# %%
#  abstract
from abc import ABC,abstractmethod


class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
class Dog(Animal):
    def sound(self):
        return "Bank"
class Cat(Animal):
    def sound(self):
        return 'Meow'
    
    
d=Dog()
print(d.sound())


e=Cat()
print(e.sound())
# Out:
# Bank
# Meow

# %%
# encapsulation



class person:
    def __init__(self,firstname,lastname,midname):
        self.firstname=firstname
        self.lastname=lastname
        self.midname=midname
        
        
        
        def set_name(self,lastname):
            return self.lastname
        
        
        def mid_name(self,firstname):
            return self.firstname






p=person('uvesh','qureshi','irshad')

print(p.firstname)       
print(p.midname)

print(p.lastname)
# Out:
# uvesh
# irshad
# qureshi

# %%
# 2. example encapsulation


class BankAccount:
    def __init__(self,account_holder,balance):
        self.account_holder=account_holder
        self.balance=balance
        
        
        
    def get_balance(self):
        return self.balance
    
    
    def doposite(self,amount):
        if amount > 0:
            self.balance+=amount
            print(f'{amount} deposite')
        else:
            print('Amount must be positive')
    def withdrow(self,amount):
        if amount<=self.balance:
            self.balance-=amount
            
            print(f'{amount} withdrown.')
        else:
            print("Insufficient balance")
            
    
acc=BankAccount('rohit',1000)
print()

# %%
# 20-11-25
from  datetime import datetime

a=datetime.today()
print(a)


dob=datetime(2000,01,01)
# Out:
# 2025-11-29 12:07:29.581679

# %%
from dateutil.relativedelta import  relativedelta
diff=relativedelta(a,dob)
print(f"{diff.years} year,{diff.months} month,{diff.day} day")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from dateutil.relativedelta import  relativedelta
# ----> 2 diff=relativedelta(a,dob)
#       3 print(f"{diff.years} year,{diff.months} month,{diff.day} day")
#
# NameError: name 'dob' is not defined

# %%
# shoping card prohram


class Shopping_Cart:
    def __init__(self,**kwargs):

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
        else:
            print('Invalid amount')

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print('Insufficient balance')

    def get_balance(self):
        return self.__balance


acc = BankAccount(5000)
acc.deposit(1500)
acc.withdraw(200)

print("Current Balance:", acc.get_balance())
# Out:
# Current Balance: 6300

# %%
class Animal:
    def sound(self):
        return 'bank '
class cat:
    def sound(self):
        return 'Meow'
    
class cow:
    def college(self):
        return 'hello'
    
    
a=Animal()
ca=cat()
co=cow()



ca.sound()
co.college()
# Out:
# 'hello'

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    
    def sound(self):
        pass
    
    def dog(self):
        print('dog')
        
class Dog(Animal):
    def sound(self):
        print('bamk')
        
class Cat(Animal):
    def sound(self):
        print('hello sir')

d = Dog()
c=Cat()
d.sound()
c.sound()
# Out:
# bamk
# hello sir

# %%
# Out:
#   Cell In[3], line 5
#     excepy as e
#     ^
# SyntaxError: expected 'except' or 'finally' block
