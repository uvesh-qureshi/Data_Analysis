# %%
print('hello')
# Out:
# hello

# %%
print('hello sir')
# Out:
# hello sir

# %%
def sum(a,b):
    return a+b

sum(12,34)
# Out:
# 46

# %%
# function in python
def hello():
    print("hello claass")
hello()
# Out:
# hello claass

# %%
# def hello(name):
#     print('hello uvesh',name)
    
# hello("qureshi")
# Out:
# hello uvesh qureshi

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2     a=input('enter the value a')
#       3     b=input('enter the value b')
# ----> 4     print(a/b)
#       5 except (ZeroDivisionError) as e:
#       6     print('error',e)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
try:
    a=int(input('enter the value of a'))
    b=int(input('enter the value of b'))
    print(a/b)
except ZeroDivisionError as e:
    print('error',e)
finally:
    print('i m uvesh qureshi')
# Out:
# error division by zero
# i m uvesh qureshi

# %%
try:
    int('abc')
except ValueError as e:
    print('error :',e)
else:
    print('no error occured')
# Out:
# error : invalid literal for int() with base 10: 'abc'

# %%
try:
    int('abc')
except ValueError as e:
    print('error',e)
else:
    print('no error occurred')
# Out:
# error invalid literal for int() with base 10: 'abc'
