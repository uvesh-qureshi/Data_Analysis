# %%
# Constructor in Python :

# A constructor in Python is a special method used to initialize an object when it is created.
# When we create an object of a class, the constructor is automatically called.

# In Python, the constructor is written using the method __init__()

# %%
print('jdsj')
# Out:
# jdsj

# %%
# Syntax of Constructor:-
class ClassName:
    def __init__(self):
        # initialization code

# __init__() → constructor method

# self → represents the current object of the class
# Out:
#   Cell In[2], line 8
#     # self → represents the current object of the class
#                                                        ^
# _IncompleteInputError: incomplete input

# %%
class Student:
    def __init__(self):
        print("Constructor is called")

std1 = Student()
# Out:
# Constructor is called

# %%
class Std:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)

s = Std("Rahul", 20)
s.display()
# Out:
# Name: Rahul
# Age: 20

# %%
# Type of constructor:
# 1. Default constructor
# 2. Parameterised constructor

# %%
# Default constructor: A constructor that does not take parameter.

# %%
class Test1:
    def __init__(self):
        print("Default Constructor")

T=Test1()
# Out:
# Default Constructor

# %%
class Demo_22:
    def __init__(self):
        print("This is a Default Constructor")

# Creating object
obj = Demo_22()
# Out:
# This is a Default Constructor

# %%
# Parameterized constructor:class Test:
def __init__(self, a, b):
    self.a = a
    self.b = b

# %%
class Std:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def display(self):
        print("Name:", self.name)
        print("Marks:", self.marks)

# Creating object
s = Std("Aman", 85)
s.display()
# Out:
# Name: Aman
# Marks: 85

# %%
# Constructor with Default Values:
class Employee:
    def __init__(self, name="Unknown", salary=0):
        self.name = name
        self.salary = salary

    def show(self):
        print("Name:", self.name)
        print("Salary:", self.salary)

# Different objects
e1 = Employee()
e2 = Employee("Rahul", 50000)

e1.show()
e2.show()
# Out:
# Name: Unknown
# Salary: 0
# Name: Rahul
# Salary: 50000
